# %% [markdown]
# <div style="border:solid purple 5px; padding: 20px">
#
# <b>Здравствуй, Олег!</b>
#
# Меня зовут Даша Абраменкова и я буду проверять твой проект 🐍. Если не против, то давай общаться на "ты", но если это не удобно, то обязательно дай знать. Как и в случае, если некомфортно обращение по имени — просто дай знать и все переиграем 😃
# Моя задача в первую и единственную очередь — помочь тебе погрузиться в анализ данных и лучше разобраться в предметной области, а совсем не поиск ошибок в домашнем задании (хотя иногда может выглядеть именно так).
# <hr>
# Для упрощения коммуникации мои пометки будут в отдельных Markdown ячейках. <b>Пожалуйста, не удаляй и не меняй их</b> — так будет проще отслеживать внесенные изменения. К слову о доработках. Будет намного удобнее, если о сделанных изменениях ты так же сообщишь мне в отдельной Markdown ячейке (это позволит принять проект куда быстрее).
#
# <hr>
# Несколько  слов об оформлении. Мои комментарии будут оформлены тремя цветами:
#
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера</b>   — зеленый комментарий означает, что эта часть работы выполнена отлично;</div>
#
# <div class="alert alert-warning">
# <b>🕵️‍♀️  Комментарий ревьюера </b> — желтый цвет укажет на хорошо проделанную работу и предложит (хоть это и необязательно) немного доработать текущий этап проекта;</div>
#
# <div class="alert alert-danger">
# <b> 👨‍🚒  Комментарий ревьюера</b> — красный комментарий означает, что некоторые аспекты придется изменить, так как без их исправления работу принять я не смогу.</div>
#
#
# <div class="alert alert-info">
# <b>Комментарий студента </b> — если хочешь, то можешь использовать синий цвет для своих комментариев, скопировав разметку из этой ячейки</div>
# <hr>
#
#
# </div>

# %% [markdown]
# <div style="border:solid green 10px; padding: 20px">
#
# <b>Дважды привет, Олег!</b>
#
# Ты отлично поработал с моими комментариями, допилив свой проект до того состояния, когда так и хочется написать:
#
# <b>С огромным удовольствием принимаю твою работу!</b>
#
# Продолжай в том же духе и у тебя все обязательно получится 💪
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Общая-статистика" data-toc-modified-id="Общая-статистика-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Общая статистика</a></span></li><li><span><a href="#Стиль-заголовков" data-toc-modified-id="Стиль-заголовков-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Стиль заголовков</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Изменение-типа-данных" data-toc-modified-id="Изменение-типа-данных-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Изменение типа данных</a></span></li><li><span><a href="#Обработка-дубликатов" data-toc-modified-id="Обработка-дубликатов-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Обработка дубликатов</a></span></li><li><span><a href="#Расчет-суммарных-продаж-по-регионам" data-toc-modified-id="Расчет-суммарных-продаж-по-регионам-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Расчет суммарных продаж по регионам</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Отбор-актуальных-для-анализа-данных" data-toc-modified-id="Отбор-актуальных-для-анализа-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Отбор актуальных для анализа данных</a></span><ul class="toc-item"><li><span><a href="#Динамика-количества-игр-по-годам" data-toc-modified-id="Динамика-количества-игр-по-годам-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Динамика количества игр по годам</a></span></li><li><span><a href="#Топ-платформы-по-продажам" data-toc-modified-id="Топ-платформы-по-продажам-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Топ-платформы по продажам</a></span></li><li><span><a href="#Временная-динамика-продаж-топ-платформ" data-toc-modified-id="Временная-динамика-продаж-топ-платформ-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Временная динамика продаж топ-платформ</a></span></li><li><span><a href="#Актуальные-для-анализа-платформы-и-период-продаж" data-toc-modified-id="Актуальные-для-анализа-платформы-и-период-продаж-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Актуальные для анализа платформы и период продаж</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Выводы</a></span></li><li><span><a href="#Исследование-актуальных-данных" data-toc-modified-id="Исследование-актуальных-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование актуальных данных</a></span><ul class="toc-item"><li><span><a href="#Продажи-на-актуальных-платформах" data-toc-modified-id="Продажи-на-актуальных-платформах-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Продажи на актуальных платформах</a></span></li><li><span><a href="#Связь-продаж-на-PS4-с-отзывами-пользователей-и-критиков" data-toc-modified-id="Связь-продаж-на-PS4-с-отзывами-пользователей-и-критиков-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Связь продаж на PS4 с отзывами пользователей и критиков</a></span></li><li><span><a href="#Связь-продаж-на-остальных-актуальных-платформах--с-оценками-пользователей-и-критиков" data-toc-modified-id="Связь-продаж-на-остальных-актуальных-платформах--с-оценками-пользователей-и-критиков-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Связь продаж на остальных актуальных платформах  с оценками пользователей и критиков</a></span></li><li><span><a href="#Жанры-на-актуальных-платформах" data-toc-modified-id="Жанры-на-актуальных-платформах-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Жанры на актуальных платформах</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Портрет-пользователя-для-каждого-региона" data-toc-modified-id="Портрет-пользователя-для-каждого-региона-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Портрет пользователя для каждого региона</a></span><ul class="toc-item"><li><span><a href="#Топ-5-платформ-по-регионам" data-toc-modified-id="Топ-5-платформ-по-регионам-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Топ-5 платформ по регионам</a></span></li><li><span><a href="#Топ-5-жанров-по-регионам" data-toc-modified-id="Топ-5-жанров-по-регионам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Топ-5 жанров по регионам</a></span></li><li><span><a href="#Рейтинг-ESRB-и-количество-проданных-игр-по-регионам" data-toc-modified-id="Рейтинг-ESRB-и-количество-проданных-игр-по-регионам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Рейтинг ESRB и количество проданных игр по регионам</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Статистический-анализ-данных" data-toc-modified-id="Статистический-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Статистический анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-средних-пользовательских-рейтингов-платформ-Xbox-One-и-PC" data-toc-modified-id="Анализ-средних-пользовательских-рейтингов-платформ-Xbox-One-и-PC-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Анализ средних пользовательских рейтингов платформ Xbox One и PC</a></span></li><li><span><a href="#Анализ-средних-пользовательских-рейтингов-жанров-Action-и-Sports" data-toc-modified-id="Анализ-средних-пользовательских-рейтингов-жанров-Action-и-Sports-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Анализ средних пользовательских рейтингов жанров Action и Sports</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Общие-выводы" data-toc-modified-id="Общие-выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общие выводы</a></span></li></ul></div>

# %% [markdown]
# # Закономерности успешной компьютерной игры

# %% [markdown]
# Описание проекта
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру
# компьютерные игры.
# Из открытых источников доступны исторические данные о
# продажах игр, оценки пользователей и экспертов, жанры и платформы
# (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность
# игры закономерности. Это позволит сделать ставку на потенциально популярный
# продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы
# планируете кампанию на 2017-й. Нужно отработать принцип работы с данными.
# Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же
# 2027-й — по данным 2026 года.
#
#
# **Цели:**
# 1) Выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# **План:**
#
# Шаг 1. Подготовка данных.
# - Замените названия столбцов (приведите к нижнему регистру);
# - Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# - Обработайте пропуски при необходимости: Объясните, почему заполнили пропуски определённым образом или почему не стали это делать; Опишите причины, которые могли привести к пропускам;
# - Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его
# обработать;
# - Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# Шаг 2. Исследовательский анализ данных.
# - Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все
# периоды?
# - Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# - Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. Не учитывайте в работе данные за предыдущие годы.
# - Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# - Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# - Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# - Соотнесите выводы с продажами игр на других платформах.
# - Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# Шаг 3. Составьте портрет пользователя каждого региона.
#
# - Определите для пользователя каждого региона (NA, EU, JP):
#   - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
#   - Самые популярные жанры (топ-5). Поясните разницу.
#   - Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# Шаг 4. Статистический анализ данных.
# Проверьте гипотезы:
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен игры) и Sports (англ. «спортивные соревнования») разные.
#
# Шаг 5. Общие выводы.

# %% [markdown]
# ## Подготовка данных

# %%
# импорт библиотек
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats as st
import numpy as np
import math as mt
import warnings                                 # для предупреждений в программе 
warnings.filterwarnings('ignore')               # игнорировать предупреждения

# %%
# создание переменной с датафреймом из файла 
df = pd.read_csv('/datasets/games.csv')

# С помощью pd.set_option настроим вывод так чтобы
pd.set_option('display.max_columns', None)             # текст в ячейке отражался полностью вне зависимости от длины
pd.set_option('display.float_format', '{:.2f}'.format) # все числа отражались с двумя знаками после запятой.

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# Супер, что настраиваешь юпитер под себя 👍
# </div>

# %% [markdown]
# ### Описание данных
#
# Name — название игры
# Platform — платформа
# Year_of_Release — год выпуска
# Genre — жанр игры
# NA_sales — продажи в Северной Америке (миллионы проданных копий)
# EU_sales — продажи в Европе (миллионы проданных копий)
# JP_sales — продажи в Японии (миллионы проданных копий)
# Other_sales — продажи в других странах (миллионы проданных копий)
# Critic_Score — оценка критиков (максимум 100)
# User_Score — оценка пользователей (максимум 10)
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваиваетим подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# Данные за 2016 год могут быть неполными.

# %%
# случайная выборка из 5 строк
display(df.sample(5))
# общая информация о датасете
df.info()
# Out:
#                                             Name Platform  Year_of_Release  \
# 10642                                       Myst       DS          2007.00
# 13606                 Starry ? Sky: After Spring      PSP          2009.00
# 6348                                      MotoGP      PS2          2000.00
# 365    Tomb Raider III: Adventures of Lara Croft       PS          1997.00
# 4349                         WWE WrestleMania 21       XB          2005.00
#
#            Genre  NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score  \
# 10642  Adventure      0.09      0.00      0.00         0.01         43.00
# 13606       Misc      0.00      0.00      0.04         0.00           NaN
# 6348      Racing      0.06      0.05      0.14         0.02         77.00
# 365       Action      1.66      1.58      0.12         0.18           NaN
# 4349    Fighting      0.34      0.10      0.00         0.02         56.00
#
#       User_Score Rating
# 10642        3.5      E
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# Выбирать случайные строки для обзора — мое почтение :)
# </div>

# %% [markdown]
# ### Общая статистика

# %%
# по числовым значениям
df.describe()
# Out:
#        Year_of_Release  NA_sales  EU_sales  JP_sales  Other_sales  \
# count         16446.00  16715.00  16715.00  16715.00     16715.00
# mean           2006.48      0.26      0.15      0.08         0.05
# std               5.88      0.81      0.50      0.31         0.19
# min            1980.00      0.00      0.00      0.00         0.00
# 25%            2003.00      0.00      0.00      0.00         0.00
# 50%            2007.00      0.08      0.02      0.00         0.01
# 75%            2010.00      0.24      0.11      0.04         0.03
# max            2016.00     41.36     28.96     10.22        10.57
#
#        Critic_Score
# count       8137.00
# mean          68.97
# std           13.94
# min           13.00
# 25%           60.00
# 50%           71.00
# 75%           79.00
# max           98.00

# %%
# по строковым значениям
df.describe(include='object')
# Out:
#                                Name Platform   Genre User_Score Rating
# count                         16713    16715   16713      10014   9949
# unique                        11559       31      12         96      8
# top     Need for Speed: Most Wanted      PS2  Action        tbd      E
# freq                             12     2161    3369       2424   3990

# %% [markdown]
# Прежде необходимо изменить тип данных в колонке user_score с object на float - столбец содержит вещественные значения оценок пользователей.

# %% [markdown]
# ### Стиль заголовков

# %% [markdown]
# Проверка стиля заголовков.

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'NA_sales', 'EU_sales',
#        'JP_sales', 'Other_sales', 'Critic_Score', 'User_Score', 'Rating'],
#       dtype='object')

# %% [markdown]
# Исправление стиля заголовков.

# %%
# Приведём столбцы к нижнему регистру.
df.columns = df.columns.str.lower()
print('Стиль заголовков исправлен:')
df.columns
# Out:
# Стиль заголовков исправлен:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# ### Обработка пропусков

# %%
# посмотрим количество пропусков в каждой из колонок
df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# Посмотрим на строки с пропусками в колонках name и genre.

# %%
df.loc[df['name'].isna() == True].sample(2)
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 14244  NaN      GEN          1993.00   NaN      0.00      0.00      0.03
# 659    NaN      GEN          1993.00   NaN      1.78      0.53      0.00
#
#        other_sales  critic_score user_score rating
# 14244         0.00           NaN        NaN    NaN
# 659           0.08           NaN        NaN    NaN

# %% [markdown]
# Эти пропуски находятся в одних строках, и их появление могло быть связано с технической ошибкой копирования данных. Пропуски в колонке genre могут в дальнейшем повлиять на корректность данных при их группировке. Поскольку здесь мы имеем всего 2 строки, а подобрать адекватную замену не представляется возможным, то лучшим решением будет их удалить.

# %%
print('Количество пропусков в колонках name:', df['name'].isna().sum(), 'и genre:', df['genre'].isna().sum(), 'до')
df = df.dropna(subset=['name'])
print('Количество пропусков в колонках name:', df['name'].isna().sum(), 'и genre:', df['genre'].isna().sum(), 'после удаления')
# Out:
# Количество пропусков в колонках name: 2 и genre: 2 до
# Количество пропусков в колонках name: 0 и genre: 0 после удаления

# %% [markdown]
# Пропуски в колонке с годом выпуска игры могут быть также связаны с технической ошибкой, либо отсутствием информации, если игра достаточно старая и была выпущена ограниченным тиражом. Узнать год релиза игры мы также не имеем возможности, также, как и заменить пропуски каким-либо адекватным значением. Поскольку строк с пропусками меньше 2%, можно без последствий отфильтровать их.

# %%
df = df.dropna(subset=['year_of_release'])

# %% [markdown]
# В колонке user_score встречается значение "tbd". Кембриджский словарь дает перевод этой аббревиатуры как to be decided or to be determined. Такая аббревиатура используется, когда что-то еще не решено или еще не известно. В данном случае такая аббревиатура эквивалентна значению "None" - оценка была не известна на момент заполнения таблицы. Произведем соответствующую замену в колонке, чтобы иметь возможность изучить пропуски дальше.

# %%
df.loc[df['user_score'] == 'tbd', 'user_score'] = 'None'
df['user_score'].describe(include='object')
# Out:
# count     9839
# unique      96
# top       None
# freq      2376
# Name: user_score, dtype: object

# %% [markdown]
# Чтобы произвести дальнейший сравнительный анализ пропусков, изменим тип данных в колонке user_score с object на float - столбец содержит вещественные значения оценок пользователей.

# %%
# используем метод to_numeric(), который способен обрабатывать возникающие ошибки
# в параметре errors поставим 'coerce' - некорректные значения принудительно заменятся на NaN

df['user_score'] = pd.to_numeric(df['user_score'], errors='coerce')

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# Должна подчеркнуть, что это очень эллегантное решение для обработки значений 🔥
# </div>

# %% [markdown]
# Проверим статистику по измененной колонке user_score.

# %%
df['user_score'].describe()
# Out:
# count   7463.00
# mean       7.13
# std        1.50
# min        0.00
# 25%        6.40
# 50%        7.50
# 75%        8.20
# max        9.70
# Name: user_score, dtype: float64

# %% [markdown]
# Минимальное значение: 0. Изучим строки с такими значениями.

# %%
df.loc[df['user_score'] == 0].count()
df.loc[df['user_score'] == 0].sample()
# Out:
#                                     name platform  year_of_release      genre  \
# 2835  My Little Pony: Pinkie Pie's Party       DS          2008.00  Adventure
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 2835      0.66      0.00      0.00         0.06           NaN        0.00
#
#      rating
# 2835      E

# %% [markdown]
# В user_score всего одна строка с нулевым значением. По игре My Little Pony: Pinkie Pie's Party в английской Википедии даже есть статья и там нет ни слова о том, что это настолько провальная игра, чтобы давать ей такой уникальный балл как 0. Поэтому будем считать, что в данном случае 0 - это плейсхолдер NaN. Заменим 0 на NaN.

# %%
df.loc[df['user_score'] == 0, 'user_score'] = np.nan

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# Никому от тебя не скрыться. Ты очень внимательный
#
# <b>Так держать!</b>
# </div>

# %% [markdown]
# Сравним количество пропусков в колонках user_score, critic_score и rating по годам.

# %%
# для этого создадим сводные таблицы по годам со срезами с пропусками, подсчитав их общее количество в каждой колонце

crit_nan = (df.loc[df['critic_score'].isna()==True]
                .pivot_table(index='year_of_release', values='name', aggfunc='count')
                .reset_index()
                     )
users_nan = (df.loc[df['user_score'].isna()==True]
                .pivot_table(index='year_of_release', values='name', aggfunc='count')
                .reset_index()
                     )

esrb_nan = (df.loc[df['rating'].isna()==True]
                .pivot_table(index='year_of_release', values='name', aggfunc='count')
                .reset_index()
                     )

# и сводную таблицу по годам и общему количеству игр
not_nan = (df.pivot_table(index='year_of_release', values='name', aggfunc='count')
             .reset_index()
                     )

# %%
# построим сводный график по таблицам
fig, ax = plt.subplots(figsize=(12, 7))
ax.set(title='Количество пропущенных оценок игр по годам их выпуска',
       xlabel='год выпуска', ylabel='количество игр')
ax.plot(crit_nan['year_of_release'], crit_nan['name'], '.--c', label='пропуки в оценках критиков')
ax.plot(users_nan['year_of_release'], users_nan['name'], '.:m', label='пропуски в оценках пользователей', color='black')
ax.plot(esrb_nan['year_of_release'], esrb_nan['name'], '.:m', label='пропуски в рейтинге ESRB', color='red')
ax.plot(not_nan['year_of_release'], not_nan['name'], '.:m', label='общее количество игр', color='green')
ax.grid=True
ax.legend(frameon=False)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# ![](https://i.gifer.com/87u0.gif)
# </div>

# %% [markdown]
# <a id='plot'></a>
# На графике видно, что кривые пропусков в оценках критиков и пользователей в целом повторяют кривую общего количества выпускаемых игр. Помимо прочих разных технических и человеческих факторов, приводящих к появлению пропусков, из анализа этого графика  можно предположить, что количество пропусков могло увеличиваться в ситуации, когда игр на рынке было больше, чем пользователи и критики могли оценить.
#
# Каким-либо образом заменить пропуски в колонках user_score, critic_score и rating мы не можем. Удалить строки с пропусками также нельзя потому, что их доля достигает более половины всех значений. Поэтому единственным решением остается ничего не предпринимать с ними в колонках user_scoreи  critic_score. И заполнить заглушкой "unknown" в колонке rating потому, что она содержит категориальные переменные.

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# Мудро
# </div>

# %%
df['rating'] = df['rating'].fillna('unknown')

# %% [markdown]
# В четырех колонках с данными по продажам игр минимальные значения - это нули. Но в данном случае - это нормально, поскольку часть игр могла не продаваться на этих рынках. Посмотрим количество записей с нулями.

# %%
df.loc[df['na_sales'] == 0, 'na_sales'].count()
# Out:
# 4449

# %%
df.loc[df['eu_sales'] == 0, 'eu_sales'].count()
# Out:
# 5766

# %%
df.loc[df['jp_sales'] == 0, 'jp_sales'].count()
# Out:
# 10300

# %%
df.loc[df['other_sales'] == 0, 'other_sales'].count()
# Out:
# 6492

# %% [markdown]
# Предположение косвенно подтверждается существенно большим количеством нулей на японском рынке, который традиционно является обособленным от остального мира.

# %% [markdown]
# Количество пропусков после обработки.

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         8982
# rating                0
# dtype: int64

# %% [markdown]
# ### Изменение типа данных

# %% [markdown]
# Изменим тип данных в колонке year_of_release с float на int (колонка содержит целочисленные значения годов).

# %%
df['year_of_release'] = df['year_of_release'].astype(int)
#df.info()

# %% [markdown]
# В колонке user_score тип данных был изменен ранее в разделе "Обработка пропусков".

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# Проверим на дубликаты.

# %%
# на явные дубликаты
print('Количество строк-дубликатов равно {}.'.format(df.duplicated().sum()))
# Out:
# Количество строк-дубликатов равно 0.

# %% [markdown]
# Посмотрим на уникальные значения в колонке name.

# %%
df['name'].value_counts()
# Out:
# Need for Speed: Most Wanted                                    12
# FIFA 14                                                         9
# LEGO Marvel Super Heroes                                        9
# Ratatouille                                                     9
# FIFA 15                                                         8
#                                                                ..
# Dragon Ball Z: Budokai Tenkaichi                                1
# Sing Party                                                      1
# Cartoon Network Collection: Game Boy Advance Video Volume 2     1
# The House of the Dead: Overkill - Extended Cut                  1
# SD Gundam G Generation Neo                                      1
# Name: name, Length: 11426, dtype: int64

# %% [markdown]
# Имеется несколько повторяющихся названий. Посмотрим строки с ними.

# %%
#df.loc[df['name'] == 'Need for Speed: Most Wanted'].sample(12) 
#df.loc[df['name'] == 'Ratatouille'].sample(9) 
#df.loc[df['name'] == 'FIFA 14'].sample(9) 
#df.loc[df['name'] == 'Madden NFL 07'].sample(9) 
#df.loc[df['name'] == 'LEGO Marvel Super Heroes'].sample(9)

# %% [markdown]
# Во всех 5 изученных случаях одна и та же игра выходила на разных платформах и продавалась и оценивалась как отдельный релиз. Поэтому это не дубликаты.

# %% [markdown]
# Посмотрим на уникальные значения в колонке platform.

# %%
df['platform'].sort_values().unique()
# Out:
# array(['2600', '3DO', '3DS', 'DC', 'DS', 'GB', 'GBA', 'GC', 'GEN', 'GG',
#        'N64', 'NES', 'NG', 'PC', 'PCFX', 'PS', 'PS2', 'PS3', 'PS4', 'PSP',
#        'PSV', 'SAT', 'SCD', 'SNES', 'TG16', 'WS', 'Wii', 'WiiU', 'X360',
#        'XB', 'XOne'], dtype=object)

# %% [markdown]
# 31 различные консоли/платформы, на которых вышли игры не дублируются.

# %% [markdown]
# Посмотрим на уникальные значения в колонке genre.

# %%
df['genre'].sort_values().unique()
# Out:
# array(['Action', 'Adventure', 'Fighting', 'Misc', 'Platform', 'Puzzle',
#        'Racing', 'Role-Playing', 'Shooter', 'Simulation', 'Sports',
#        'Strategy'], dtype=object)

# %% [markdown]
# Жанры не дублируются.

# %% [markdown]
# Посмотрим на уникальные значения в колонке rating.

# %%
df['rating'].sort_values().unique()
# Out:
# array(['AO', 'E', 'E10+', 'EC', 'K-A', 'M', 'RP', 'T', 'unknown'],
#       dtype=object)

# %% [markdown]
# Типы рейтинга не дублируются.

# %% [markdown]
# ### Расчет суммарных продаж по регионам

# %% [markdown]
# Посчитаем суммарные продажи во всех регионах и запишем их в отдельную колонку.

# %%
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']

# поменяем последовательность колонок на более удобную
df = df[['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales',
        'total_sales', 'critic_score', 'user_score', 'rating']]

df.sample(3)
# Out:
#                               name platform  year_of_release      genre  \
# 3736                    The Hobbit      PS2             2003   Platform
# 4313   Enemy Territory: Quake Wars     X360             2008    Shooter
# 14476       Highschool Terra Story      SAT             1998  Adventure
#
#        na_sales  eu_sales  jp_sales  other_sales  total_sales  critic_score  \
# 3736       0.26      0.20      0.00         0.07         0.53         59.00
# 4313       0.30      0.11      0.00         0.04         0.45         69.00
# 14476      0.00      0.00      0.03         0.00         0.03           NaN
#
#        user_score   rating
# 3736         8.60        E
# 4313         7.30        T
# 14476         NaN  unknown

# %% [markdown]
# Дополнительные данные в таблице df:
# - total_sales - суммарные продажи игр по всем регионам (миллионы проданных копий).

# %% [markdown]
# ### Выводы
#
# 1. Данные содержат информацию об играх, выпущенных на 31 платформе с 1980 по 2016 годы, об их жанре, продажах в 4 регионах, оценках критиков и пользователей и возрастном рейтинге от организации ESRB.
# 2. Исправлен стиль заголовков.
# 3. Обработаны пропуски в колонках: name, year_of_release, genre и rating .
# 4. Пропуски в колонках critic_score и user_score оставлены без изменений, поскольку нет возможности их заменить адекватными значениями или удалить, т.к. их доля достигает более половины всех значений.
# 5. Изменен тип данных в столбцах (в скобках на какой тип): year_of_release (int), user_score (float).
# 6. Дубликатов не найдено.
# 7. Добавлена колонка total_sales с суммарными продажами по всем регионам.

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# Ты очень и очень тщательно проводишь подготовку данных к исследованию. Да еще и используешь красивый, чистый код с комментариями, снабжая каждый шаг исчерпывающими, но не чрезмерными выводами. Честно признаюсь, что редко когда проверка этого раздела доставляет такое удовольствие. Спасибо, за твой подход 😌
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Привет, Даша! Спасибо за такую вдохновляющую оценку моего труда)</div>
# <hr>

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера (v.2)</b>
#
# Рада быть полезной :)
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Отбор актуальных для анализа данных

# %% [markdown]
# #### Динамика количества игр по годам
#
# Посмотрим сколько игр выпускалось в разные годы. Будем иметь в виду, что данные за 2016 год могут быть неполными.

# %%
# сводные таблицы.
years_games = df.pivot_table(index='year_of_release',
                             values='name', 
                             aggfunc='count')

# построим график 
plt.figure(figsize=(15,7))
sns.barplot(x=years_games.index, y=years_games['name'], color='mediumseagreen') 
plt.xticks(rotation= 45)
plt.title('Количество игр по годам', size=16)
plt.xlabel('год выпуска', size=14)
plt.ylabel('количество выпущенных игр', size=14)
plt.show()

# %% [markdown]
# На графике видно, что с 1994 года начинается заметный рост, с 2001 количество игр сравнимо с годами после 2013, а с 2002 по 2012 объемы ежегодных релизов значительно превосходят остальные периоды.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🕵️‍♀️  Комментарий ревьюера </b>
#
# А надо ли нам тащить с собой данные за все периоды?
# </div>

# %% [markdown]
# #### Топ-платформы по продажам
#
# Выберем платформы с наибольшими суммарными продажами.

# %%
# посчитаем суммарные продажи для каждой платформы
platform_sales = df.pivot_table(index='platform', values='total_sales', aggfunc=sum)\
                                     .sort_values(by='total_sales', ascending=False)

# построим график по сводной таблице
plt.figure(figsize=(14,6))
sns.barplot(x=platform_sales.index, y=platform_sales['total_sales'], palette='Set3')
plt.title('Продажи по платформам', fontsize=16)
plt.xticks(rotation= 45, size=12)
plt.xlabel('платформы', size=14)
plt.ylabel('миллионы проданных копий', size=14)
plt.show()

# %% [markdown]
# Топ-6 платформ по продажам: PS2, X360, PS3, Wii, DS, PS.

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# Мне бы тоже не захотелось обрезать первую PS))))
# </div>

# %% [markdown]
# #### Временная динамика продаж топ-платформ
#
# Построим распределение для топ-6 платформ с наибольшими суммарными продажами по годам.

# %%
# список с топ-платформами, по которому будем фильтровать данные для сводной таблицы
tops = ['PS2','X360','PS3','Wii', 'DS','PS']

# сводная таблица
top_platform_sales = (df
                        .loc[df['platform'].isin(tops)]
                        .pivot_table(index=['platform', 'year_of_release'], values='total_sales', aggfunc='sum')
                        .reset_index()
                     )

# график по таблице
plot = sns.catplot(x='year_of_release', y='total_sales', hue='platform', kind='bar', data=top_platform_sales, palette='Set1')
plt.title("Продажи на топ-6 платформах", fontsize=15)
plt.xlabel('год выпуска', fontsize=12)
plt.ylabel('миллионы проданных копий', fontsize=12)
plot.fig.set_size_inches(20,7)
plt.show()

# %% [markdown]
# Характерный срок жизни платформы - около 10 лет. Все плтаформы с топ-продажами практически исчезли с рынка, поэтому данные по ним не актуальны.

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# Совершенно согласна с оценкой в 10 лет
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>🕵️‍♀️  Комментарий ревьюера </b>
#
# Беусловно, вкусовщина, но мне кажется, что для динамики рынка больше подошел тот же график, которым ты оценивал пропуски в оценках
# </div>

# %% [markdown]
# #### Актуальные для анализа платформы и период продаж
#
# Определим актуальные платформы и период продаж игр для них, чтобы эти данные помогли построить прогноз на 2017 год.

# %%
platforms_1 = ['PS4','GBA','PSP','3DS', 'PC','GB']

platforms_sales_1 = (df
                        .loc[df['platform'].isin(platforms_1)]
                        .pivot_table(index=['platform', 'year_of_release'], values='total_sales', aggfunc='sum')
                        .reset_index()
                     )


plot_1 = sns.catplot(x='year_of_release', y='total_sales', hue='platform', kind='bar', data=platforms_sales_1, palette='Set1')
plt.title("Продажи по платформам", fontsize=15)
plt.xlabel('год выпуска', fontsize=12)
plt.ylabel('миллионы проданных копий', fontsize=12)
plot_1.fig.set_size_inches(20,7)
plt.show()

platforms_2 = ['XB','NES','N64','SNES', 'GC','XOne']

platforms_sales_2 = (df
                        .loc[df['platform'].isin(platforms_2)]
                        .pivot_table(index=['platform', 'year_of_release'], values='total_sales', aggfunc='sum')
                        .reset_index()
                     )


plot_2 = sns.catplot(x='year_of_release', y='total_sales', hue='platform', kind='bar', data=platforms_sales_2, palette='Set1')
plt.title("Продажи по платформам", fontsize=15)
plt.xlabel('год выпуска', fontsize=12)
plt.ylabel('миллионы проданных копий', fontsize=12)
plot_2.fig.set_size_inches(20,7)
plt.show()

platforms_3 = ['2600','WiiU','PSV','SAT', 'GEN','DC']

platforms_sales_3 = (df
                        .loc[df['platform'].isin(platforms_3)]
                        .pivot_table(index=['platform', 'year_of_release'], values='total_sales', aggfunc='sum')
                        .reset_index()
                     )


plot_3 = sns.catplot(x='year_of_release', y='total_sales', hue='platform', kind='bar', data=platforms_sales_3, palette='Set1')
plt.title("Продажи по платформам", fontsize=15)
plt.xlabel('год выпуска', fontsize=12)
plt.ylabel('миллионы проданных копий', fontsize=12)
plot_3.fig.set_size_inches(20,7)
plt.show()

# %% [markdown]
# ### Выводы
#
# 1. Актуальными платформами являются:
# - три стационарные: подключаемые к телевизору PS4 и XOne, и PC (персональный компьютер);
# - три мобильные: 3DS, , WiiU и PSV.
#
# 2. Актуальный период для анализа: 2013-2016 гг., поскольку по всем вышеперечисленным плтаформам одновременно есть данные с 2013 года.

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# Что-то мне подсказывает, что ты не по наслышке знаком с рынком :)
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b> 👨‍🚒  Комментарий ревьюера</b>
#
# Не разделяю твоего стремления выделить только топовые платформы для всего анализа. Объясню почему.
#
# Во-первых, суммарные продажи не всегда являются надежным показателем успеха платформы. Вполне возможно, что просто разработка игр для конкретно этой платформы стоит дороже (или игр выпускается больше, а значит конкуренция выше) и от того сумма будет выше.
#
# Во-вторых, нам предстоит оценить не столько платформы, сколько игры, а обрезая отдельные (еще живые) платформы, мы лишаем себя полноты данных в жанрах, рейтингах и предпочтениям по странам.
#
# В-третьих, у тебя пропали все те платформы, что были в топ-6 по продажам.
#
# Поэтому предлагаю оставить все платформы для анализа, хоть и иметь ввиду, что интересуют нас далеко не все они.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Я правильно понял куратора в решении вопроса и мне можно не переделывать работу по этим пунктам?</div>
# <hr>

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера (v.2)</b>
#
# Да, ты правильно понял 👍
# </div>

# %% [markdown]
# ### Исследование актуальных данных

# %% [markdown]
# #### Продажи на актуальных платформах
#
# Построим график «ящик с усами» по глобальным продажам игр для актуальных платформ.

# %%
# датафрейм с актуальными платформами после 2013 года
tops_2 = ['PS4','3DS','XOne','WiiU', 'PSV','PC']
actual_platforms = df.loc[(df['platform'].isin(tops_2)) & (df['year_of_release'] >= 2013)]

# сводная таблица по актуальным платформам с глобальными продажами после 2013 года
top_platform_sales_2 = (actual_platforms
                        .pivot_table(index=['platform', 'year_of_release'], values='total_sales', aggfunc='sum')
                        .reset_index()
                     )

# боксплот по таблице
# сначала идет fig, а потом plot_top 
fig = plt.subplots(figsize=(7,7))
plot_top = sns.boxplot(x='platform', y='total_sales', data=top_platform_sales_2, palette='Set3', showfliers=False)
plt.title("Продажи на актуальных платформах", fontsize=15)
plt.xlabel('платформы', fontsize=12)
plt.ylabel('суммарные продажи (миллионы проданных копий)', fontsize=12)
plt.show()

# %% [markdown]
# Самые высокие продажи и большое распределение имеет PS4. Основная часть его значений располагается в диапазоне от 50 до 100 миллионов проданных игр, медиана в районе: 85. Распределение выглядит нормальным с некоторым левосторонним скосом. Как видно было на прошлый графиках, это связано с ростом продаж с 2013 по 2015.
# Все остальные платформы имеют значительно меньшие объемы продаж. Изучим подробнее PS4.

# %% [markdown]
# #### Связь продаж на PS4 с отзывами пользователей и критиков
#
# Посмотрим, как влияют отзывы пользователей и критиков на продажи игр на самой популярной платформе - PS4.
#
# Для этого построим матрицу корреляций.

# %%
# срез данных по продажам, оценкам критиков и пользователей для ps4 с 2013 г.
ps4 = actual_platforms.query('platform == "PS4"')

# оставим нужные колонки
ps4 = ps4[['total_sales', 'critic_score', 'user_score']]

ps4.corr()
# Out:
#               total_sales  critic_score  user_score
# total_sales          1.00          0.41       -0.03
# critic_score         0.41          1.00        0.56
# user_score          -0.03          0.56        1.00

# %% [markdown]
# И матрицу диаграмм рассеяния.

# %%
sns.pairplot(ps4)

# %% [markdown]
# Коэффициент Пирсона между продажами игр на PS4 и оценками критиков слабый. На диаграмме рассеяния заметна некоторая положительная корреляция - чем выше оценка критиков, тем больше продажи.
# Схожая, но еще более слабая и распыленная связь наблюдается между продажами игр на PS4 и оценками пользователей. Это закономерно, т.к. пользователям, в отличие от многих критиков, чтобы оценить игру, надо ее сначала купить.

# %% [markdown]
# #### Связь продаж на остальных актуальных платформах  с оценками пользователей и критиков
#
# Посмотрим, как влияют оценки пользователей и критиков на продажи игр на остальных актуальных платформах.
#
# Посчитаем корреляции оценок пользователей и критиков для каждой платформы.

# %%
# список с топ-платформами без PS4, по которому будем фильтровать данные для сводной таблицы
tops_3 = ['3DS','XOne','WiiU', 'PSV','PC']

# цикл для построения двух корреляций для каждой платформы из списка
for platform in tops_3:
    print(f'\n{platform}:')
    platform = actual_platforms[actual_platforms['platform']== platform]
    print('Корреляция между оценками критиков и продажами:', platform['critic_score'].corr(platform['total_sales']))
    print('Корреляция между оценками пользователей и продажами:', platform['user_score'].corr(platform['total_sales']))
# Out:
# 3DS:
# Корреляция между оценками критиков и продажами: 0.3570566142288103
# Корреляция между оценками пользователей и продажами: 0.24150411773563016
#
# XOne:
# Корреляция между оценками критиков и продажами: 0.4169983280084017
# Корреляция между оценками пользователей и продажами: -0.06892505328279414
#
# WiiU:
# Корреляция между оценками критиков и продажами: 0.3764149065423912
# Корреляция между оценками пользователей и продажами: 0.4193304819266187
#
# PSV:
# Корреляция между оценками критиков и продажами: 0.2547423503068656
# Корреляция между оценками пользователей и продажами: 0.0009424723319108626
#
# PC:
# Корреляция между оценками критиков и продажами: 0.19603028294369382
# Корреляция между оценками пользователей и продажами: -0.0938418695247674

# %% [markdown]
# Построим сводную матрицу диаграмм рассеяния.

# %%
# срез данных без ps4 с 2013 г.
without_ps4 = actual_platforms.loc[actual_platforms['platform'] != 'PS4']

# оставим нужные колонки
without_ps4 = without_ps4[['platform', 'total_sales', 'critic_score', 'user_score']]

# используем парный график из библиотеки seaborn
sns.pairplot(without_ps4, hue="platform")

# %% [markdown]
# Можно наблюдать похожую картину, как и в случае с  PS4. Связь между продажами игр на актуальных платформах и оценками критиков и пользователей слабая положительная - чем выше оценки, тем выше часть продаж.

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# Мои глаза замироточили от того, как удачно ты обошелся с визуализацией 🙃
#
# </div>

# %% [markdown]
# #### Жанры на актуальных платформах
#
# Посмотрим на общее распределение игр по жанрам на актуальных платформах, включая PS4.
#
# Для этого построим столбчатую диаграмму по медианным продажам (миллионы проданных копий).

# %%
genre_sales = actual_platforms.pivot_table(index='genre', 
                                     values='total_sales', 
                                     aggfunc='median').sort_values('total_sales', ascending=False)
# построим график
plt.figure(figsize=(15,7))
sns.barplot(y=genre_sales.index, x=genre_sales['total_sales'], palette='Set3')
plt.title('Рапределение медианных продаж по жанрам', fontsize=16)
plt.ylabel('Жанры', size=14)
plt.xlabel('медианные продажи', size=14)
plt.show()

genre_sales
# Out:
#               total_sales
# genre
# Shooter              0.52
# Platform             0.24
# Sports               0.23
# Role-Playing         0.12
# Fighting             0.12
# Misc                 0.10
# Racing               0.10
# Action               0.09
# Simulation           0.09
# Strategy             0.08
# Puzzle               0.07
# Adventure            0.03

# %% [markdown]
# Лидеры среди жанров по суммарным продажам:
# 1) Shooter.
# 2) Platform.
# 3) Sports.

# %%
# список с топ-жанрами, по которому будем фильтровать данные для сводной таблицы
top_genres = ['Shooter', 'Platform', 'Sports']

# сводная таблица по актуальным платформам с глобальными продажами после 2013 года
top_genres_pivot = (actual_platforms
                        .loc[actual_platforms['genre'].isin(top_genres)]
                        .pivot_table(index=['genre', 'year_of_release'], values='total_sales', aggfunc='median')
                        .reset_index()
                     )

# боксплот по таблице
# сначала идет fig, а потом plot_top 
fig = plt.subplots(figsize=(7,7))
plot_top = sns.boxplot(x='genre', y='total_sales', data=top_genres_pivot, palette='Set3', showfliers=False)
plt.title("Медианные продажи игр топ-жанров на актуальных платформах", fontsize=15)
plt.xlabel('жанры', fontsize=12)
plt.ylabel('миллионы проданных копий', fontsize=12)
plt.show()

# %%
shooter = top_genres_pivot.query('genre == "Shooter"')
platform = top_genres_pivot.query('genre == "Platform"')
sports = top_genres_pivot.query('genre == "Sports"')

try:
    fig = plt.subplots(figsize = (12,5))
    plt.xlabel('меданные продажи')
    plt.ylabel('плотность частоты')
    plt.title('Медианные продажи игр топ-жанров на актуальных платформах')
    sns.kdeplot(shooter['total_sales'], shade=True, label="Shooter")
    sns.kdeplot(platform['total_sales'], shade=True, label="Platform")
    sns.kdeplot(sports['total_sales'], shade=True, label="Sports")
    plt.legend()
except:
    print('апшипка')

# %% [markdown]
# Распределения жанров Shooter и Platform похожи, отличаются большой дисперсией, из чего можно предположить, что продажи обеспечиваются большим количеством разных игр. Чего нельзя сказать о распределении жанра Sports, отличающегося пиковой плотностью в районе 0,2, что может указывать на ограниченное количество популярных популярных игр.

# %%
sports.describe()
# Out:
#        year_of_release  total_sales
# count             4.00         4.00
# mean           2014.50         0.25
# std               1.29         0.15
# min            2013.00         0.12
# 25%            2013.75         0.16
# 50%            2014.50         0.22
# 75%            2015.25         0.31
# max            2016.00         0.46

# %% [markdown]
# <div class="alert alert-danger">
# <b>👨‍🚒 Комментарий ревьюера </b>
#
#
# Давай пойдем по порядку 🙃
#
# Общие продажи (как мы упоминули уже выше) - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи.
#
# Ты удивишься, если попробуешь взглянуть на данные под другим углом.
#
# С диаграммами, пусть и такими красивыми с легендами, как у тебя, лучше быть осторожнее. Если число категорий, которые на них выведены, больше 5 или 6, то становится очень непросто их читать. В случае, если ты хочешь именно в форме "пирога" представить свое исследование, то лучше мелкие категории объединить в одну категорию "другое" и вывести лишь самые значимые жанры. Но если ты хочешь преподнести соотношения всех жанров между собой, то, вероятно, лучшим решением станет гистограмма.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>🕵️‍♀️  Комментарий ревьюера (v.2)</b>
#
# Все же рекомендую тебе здесь построить гистограмму медианных продаж — так будет нагляднее, чем ящик с усами и может быть это изменит твои выводы.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Сделал.</div>
# <hr>

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера (v.3)</b>
#
# И выводы сразу поменялись :) Супер!
# </div>

# %% [markdown]
# ### Выводы
#
# 1. За 36 лет разнообразие платформ успело возрасти и уменьшится до нескольких игроков, главными из которых (лидерами по проданным копиям) с 2013 года являются PS4 и XOne, но также сохраняют актуальность: 3DS, WiiU, PSV и вечный PC.
# 2. Исходя из характерного срока жизни платформы (около 10 лет), вышеназванные платформы еще будут актуальны:
# - PS4 (2017-2021 гг.);
# - XOne (2017-2021 гг.);
# - 3DS (2017-2019 гг.);
# - WiiU (2017-2019 гг.);
# - PSV (2017-2019 гг.);
# PC является исключением - он существует на рынке с 1992 года и похоже не собирается его покидать.
# 3. Анализ жанров проводился по актуальным платформам и периоду с 2013 года. Лидеры среди жанров по медианным продажам (миллионы проданных копий) в порядке убывания: Shooter, Platform, Sports.
# 4. Связь между продажами игр на актуальных платформах и оценками критиков и пользователей слабая положительная - чем выше оценки, тем выше часть продаж.

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# Если писать вывод, то только такой 👍
# </div>

# %% [markdown]
# ## Портрет пользователя для каждого региона
#
# Определим для пользователя каждого региона (NA, EU, JP) на актуальных платформах с 2013 года:
#  - Самые популярные платформы (топ-5) и опишим различия в долях проданных копий игр;
#  - Самые популярные жанры (топ-5) по проданным копиям игр;
#  - Влияет ли рейтинг ESRB на продажи в отдельном регионе.

# %% [markdown]
# ###  Топ-5 платформ по регионам
#
# Определим топ-5 платфрм в каждом регионе из актуальных платформ с 2013 года и опишим различия в долях по проданным копиям игр.

# %%
# круговая диаграмма для региона NA
( actual_platforms.groupby('platform')['na_sales'].sum()
                    .sort_values(ascending = False)
                    .plot(kind = 'pie', figsize=(14, 10), 
                    title = 'Рапределение по платформам (проданные копии игр) в Северной Америке', autopct="%.2f")
)
# Out:
# <AxesSubplot:title={'center':'Рапределение по платформам (проданные копии игр) в Северной Америке'}, ylabel='na_sales'>

# %% [markdown]
# Топ-5 платформ по суммарным продажам в Северной Америке (в скобках доля в процентах):
# 1) PS4 (38,1).
# 2) X-One (32,6).
# 3) 3DS (13,3).
# 4) WiiU (10,2).
# 5) PC (3,8).

# %%
# круговая диаграмма для региона EU
( actual_platforms.groupby('platform')['eu_sales'].sum()
                    .sort_values(ascending = False)
                    .plot(kind = 'pie', figsize=(14, 10), 
                    title = 'Рапределение по платформам (проданные копии игр) в Европе', autopct="%.2f")
)
# Out:
# <AxesSubplot:title={'center':'Рапределение по платформам (проданные копии игр) в Европе'}, ylabel='eu_sales'>

# %% [markdown]
# Топ-5 платформ по суммарным продажам в Европе (в скобках доля в процентах):
# 1) PS4 (51,3).
# 2) X-One (18,7).
# 3) 3DS (11,2).
# 4) PC (9,2).
# 5) WiiU (7,2).

# %%
# круговая диаграмма для региона JP
( actual_platforms.groupby('platform')['jp_sales'].sum()
                    .sort_values(ascending = False)
                    .plot(kind = 'pie', figsize=(14, 10), 
                    title = 'Рапределение по платформам (проданные копии игр) в Японии', autopct="%.2f")
)
# Out:
# <AxesSubplot:title={'center':'Рапределение по платформам (проданные копии игр) в Японии'}, ylabel='jp_sales'>

# %% [markdown]
# Топ-4 платформы по суммарным продажам в Европе (в скобках доля в процентах):
# 1) 3DS (59,7).
# 2) PSV (16,3).
# 3) PS4 (14).
# 4) WiiU (9,5).

# %% [markdown]
# <div class="alert alert-warning">
# <b>🕵️‍♀️  Комментарий ревьюера </b>
#
# Ты же помнишь, что это топ из того топа, что ты сам сформировал?)
# </div>

# %% [markdown]
# ###  Топ-5 жанров по регионам
#
# Определим топ-5 жанров по проданным копиям игр в каждом регионе на актуальных платформах с 2013 года.

# %%
# круговая диаграмма для региона NA
( actual_platforms.groupby('genre')['na_sales'].sum()
                    .sort_values(ascending = False)
                    .plot(kind = 'pie', figsize=(14, 10), 
                    title = 'Рапределение по жанрам (проданные копии игр) в Северной Америке', autopct="%.2f")
)
# Out:
# <AxesSubplot:title={'center':'Рапределение по жанрам (проданные копии игр) в Северной Америке'}, ylabel='na_sales'>

# %% [markdown]
# Топ-5 жанров по суммарным продажам в Северной Америке:
# 1) Shooter .
# 2) Action.
# 3) Role-Playing.
# 4) Sports.
# 5) Platform.

# %%
# круговая диаграмма для региона EU
( actual_platforms.groupby('genre')['eu_sales'].sum()
                    .sort_values(ascending = False)
                    .plot(kind = 'pie', figsize=(14, 10), 
                    title = 'Рапределение по жанрам (проданные копии игр) в Европе', autopct="%.2f")
)
# Out:
# <AxesSubplot:title={'center':'Рапределение по жанрам (проданные копии игр) в Европе'}, ylabel='eu_sales'>

# %% [markdown]
# Топ-5 жанров по суммарным продажам в Европе:
# 1) Action.
# 2) Shooter.
# 3) Sports .
# 4) Role-Playing.
# 5) Racing.

# %%
# круговая диаграмма для региона JP
( actual_platforms.groupby('genre')['jp_sales'].sum()
                    .sort_values(ascending = False)
                    .plot(kind = 'pie', figsize=(14, 10), 
                    title = 'Рапределение по жанрам (проданные копии игр) в Японии', autopct="%.2f")
)
# Out:
# <AxesSubplot:title={'center':'Рапределение по жанрам (проданные копии игр) в Японии'}, ylabel='jp_sales'>

# %% [markdown]
# Топ-5 жанров по суммарным продажам в Японии:
# 1) Role-Playing.
# 2) Action.
# 3) Misc.
# 4) Fighting.
# 5) Platform.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🕵️‍♀️  Комментарий ревьюера </b>
#
# Вот тут тоже стоит оценить возможность "допила" круговой диаграммы
# </div>

# %% [markdown]
# ###  Рейтинг ESRB и количество проданных игр по регионам
#
# Посмотрим влияет ли рейтинг ESRB на количество проданных копий игр в каждом регионе на актуальных платформах с 2013 года.

# %% [markdown]
# <div class="alert alert-danger">
# <b>👨‍🚒 Комментарий ревьюера </b>
#
# А за что ты так с играми у которых нет установленного рейтинга? Это ведь, можно сказать, целая категория (да и для всех ли стран обязателен этот рейтинг?)))
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Здесь не понял, что от меня требуется. Я выяснял вопрос связи рейтинга ESRB и проданных копий. В задании не было вопроса как продаются игры без этого рейтинга. </div>
# <hr>

# %% [markdown]
# <div class="alert alert-danger">
# <b>👨‍🚒 Комментарий ревьюера (v.2)</b>
#
# Здесь нужно оставить игры без рейтинга и не фильтровать их (не использовать .query('rating not in "unknown"')). Ведь это не оценка влияния, как было с пользователями и критиками, а портрет пользователя. Например, описывая образ жизни человека, мы же примем во внимание, что он, например, не курит и не пьет. Или, напротив, то, что в жизни человека нет спорта, так же является описанием его образа жизни. Вот так же и здесь для описания "портрета пользователя" нам нужно учитывать не только тот рейтинг, который есть, но и тот, которого нет.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Понял, осознал и исправил) </div>
# <hr>

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера (v.3)</b>
#
# ![](https://media.giphy.com/media/ByeYxURXxPyptxD2ta/giphy.gif)
# </div>

# %%
# создадим сводную таблицу с суммарными продажами по регионам для каждой категории рейтинга ESRB

print('Рейтинг ESRB и суммарные продажи по регионам\n')
esrb_sales = ( actual_platforms
              .pivot_table(index='rating', values=['na_sales', 'eu_sales', 'jp_sales'], aggfunc=['sum'])
             )

# переименование столбцов для удобства восприятия
esrb_sales.columns = ['Северная Америка', 'Европа', 'Япония']
esrb_sales
# Out:
# Рейтинг ESRB и суммарные продажи по регионам
#          Северная Америка  Европа  Япония
# rating
# E                   58.00   13.26   52.37
# E10+                26.30    5.66   32.25
# M                   94.51    8.17   97.05
# T                   32.60   13.52   35.07
# unknown             63.54   72.97   68.68

# %%
# столбчатая диаграмма по сводной таблице
esrb_sales.plot(kind='bar', figsize=(12, 6)) 
plt.title('Рейтинг ESRB и количество проданных копий игр по регионам')
plt.xlabel('категории рейтинга ESRB')
plt.ylabel('миллионы проданных копий') 
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %% [markdown]
# _Категории рейтинга игры от организации ESRB:_
#
#  - «EC» («Early childhood») — «Для детей младшего возраста»
#  - «E» («Everyone») — «Для всех»
#  - «E10+» («Everyone 10 and older») — «Для всех старше 10 лет»
#  - «T» («Teen») — «Подросткам 13—19 лет»
#  - «M» («Mature») — «От 17 лет»
#  - «AO» («Adults Only 18+») — «Только для взрослых»
#  - «RP» («Rating Pending») — «Рейтинг ожидается»
#  - «K-A» («Kids to Adults»)— «Для детей и взрослых»
#
# Источник: [Рейтинги ESRB](https://www.esrb.org/)
#
# Категория "unknown" - игры без рейтинга.

# %% [markdown]
# В период с 2103 года на актуальных платформах были проданы игры с 4 категориями рейтинга: Е, Е10+, М, Т и гры без рейтинга ("unknown").
#
# Рейтинг оказывает слабое влияние на количество проданных игр.
#
# Больше всего игр в Северной Америке и Японии продаются с рейтингом М, следом идут игры без рейтинга, далее категория Е и замыкают рейтинги Е10+ и Т со схожим уровнем суммарных продаж.
#
# В случае с рейтингом ESRB Европа сильно отличается по своим показателям от Северной Америки и Японии. Здесь больше продаж у игр без рейтинга, далее идут рейтинги Т и Е, после них категория М, и замыкает категория Е10+.

# %% [markdown]
# ### Выводы
#
# 1. Геймеры Северной Америки в 2013-2016 выбирали в близкой степени прежде всего 2 игровые платформы PS4 (38,1 % от 6 актуальных платформ) и X-One (32,6 %). Среди жанров они предпочитают прежде всего Shooter (26,4 %) и Action (25,7 %). Среди рейтингов ESRB больше покупают игры категории М ("от 17 лет").
# 2. Геймеры Европы в 2013-2016 отдали свое предпочтение одной игровой платформе - PS4 (51,3 %), идущая следом X-One сильно отстала (18,7 %). Среди жанров они имеют схожие с североамериканскими предпочтения, но жанры  Action (26,9 %) и  Shooter (23,6 %) поменялись местами. Игры без рейтинга ESRB вне конкуренции в этом регионе.
# 3. Геймеры Японии в 2013-2016 отдали свое предпочтение не просто одной платформе, а мобильным платформам перед стационарными. Предпочитают они 3DS (59,7 %), следующая по популярности - PSV (16,3 %). Среди жанров они также кардинально отличаются от двух других регионов. Свои предпочтения они делят прежде всего между Role-Playing (39,4 %) и Action (26,3 %). Среди рейтингов ESRB больше покупают игры категории М ("от 17 лет"), как и их североамериканские коллеги, также популярны игры без рейтинга.

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера </b>
#
# Талант к оформлению выводов у тебя не отнять 🔥
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>🙃 </div>
# <hr>

# %% [markdown]
# ## Статистический анализ данных
#
# Проверим гипотезы:
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Средние пользовательские рейтинги жанров Action и Sports разные.

# %% [markdown]
# <div class="alert alert-danger">
# <b>👨‍🚒 Комментарий ревьюера </b>
#
# Ты дважды отлично справился с т-тестом, но есть один момент. Мы изучаем определенный (актуальный) период времени, а ты взял для проверки гипотез целиком всю таблицу. И если посмотреть на жизненный цикл ПК и Хбокса, то думаю ты поймешь, почему это не совсем корректно :)
# Но и для жанров работает так же
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Исправил) </div>
# <hr>

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера (v.2)</b>
#
# Супер 🔥
# </div>

# %%
#код ревьюера
pltf = ['XOne', 'PC']
df.query('platform in @pltf').groupby('platform').agg({'year_of_release' : ['min', 'max']})
# Out:
#          year_of_release
#                      min   max
# platform
# PC                  1985  2016
# XOne                2013  2016

# %% [markdown]
# ### Анализ средних пользовательских рейтингов платформ Xbox One и PC

# %% [markdown]
# Создадим две переменные со срезами по платформам X-One и PC без пропусков с 2013 года (начало продаж на Xbox One).

# %%
xone = df.query('platform in "XOne" and user_score.isna() != True')
pc = df.query('platform in "PC" and user_score.isna() != True and year_of_release >= 2013')

# %% [markdown]
# Посмотрим статистику по пользовательскому рейтингу для каждой платформы.

# %%
print('Средний пользовательский рейтинг. Основная статистика распределения.\n')
print('Платформа Xbox One:\n')
print(xone['user_score'].describe().astype(int), '\n')
print('Дисперсия:', np.var(xone['user_score'], ddof=1), '\n')

print('Платформа PC:\n')
print(pc['user_score'].describe().astype(int), '\n')
print('Дисперсия:', np.var(pc['user_score'], ddof=1))
# Out:
# Средний пользовательский рейтинг. Основная статистика распределения.
#
# Платформа Xbox One:
#
# count    182
# mean       6
# std        1
# min        1
# 25%        5
# 50%        6
# 75%        7
# max        9
# Name: user_score, dtype: int64
#
# Дисперсия: 1.9069968429360695
#
# Платформа PC:
#
# count    155
# mean       6
# std        1
# min        1
# 25%        5
# 50%        6
# 75%        7
# max        9
# Name: user_score, dtype: int64
#
# Дисперсия: 3.035892752408882

# %% [markdown]
# Выборки имеют разные дисперсии и различаются по размеру. Учтем это при проведении t-теста.
#
# Сформулируем статистические гипотезы из положения о том, что нулевая гипотеза всегда формулируется так, чтобы использовать знак равенства:
#
# H0 — средний пользовательский рейтинг Xbox One и PC одинаковый.
# H1 — средний пользовательский рейтинг Xbox One и PC различается.

# %%
# критический уровень статистической значимости зададим 5% поскольку у нас двусторонняя гипотеза и 
# вероятность отклониться от центра распределения в каждую сторону уменьшится до 2,5% 
# и это стандартная величина, обычно использующаяся в t-тесте
alpha = .05 

# поскольку у нас две независимые выборки, используем метод st.ttest_ind()
# equal_var=False - дисперсии выборок не равны
results = st.ttest_ind(
    xone['user_score'], 
    pc['user_score'], 
    equal_var=False) 

print('p-значение:', results.pvalue)

# сравним получившееся p-значение с заданным уровнем статистической значимости
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу. Средний пользовательский рейтинг Xbox One и PC различается.')
else:
    print('Не получилось отвергнуть нулевую гипотезу. Средний пользовательский рейтинг Xbox One и PC одинаковый')
# Out:
# p-значение: 0.14759594013430463
# Не получилось отвергнуть нулевую гипотезу. Средний пользовательский рейтинг Xbox One и PC одинаковый

# %% [markdown]
# ### Анализ средних пользовательских рейтингов жанров Action и Sports

# %% [markdown]
# Создадим две переменные со срезами по жанрам Action и Sports без пропусков.

# %%
action = df.query('genre in "Action" and user_score.isna() != True')
sports = df.query('genre in "Sports" and user_score.isna() != True')

# %% [markdown]
# Посмотрим статистику по пользовательскому рейтингу для каждой платформы.

# %%
print('Средний пользовательский рейтинг. Основная статистика распределения.\n')
print('Жанр Action:\n')
print(action['user_score'].describe().astype(int), '\n')
print('Дисперсия:', np.var(action['user_score'], ddof=1), '\n')

print('Жанр Sports:\n')
print(sports['user_score'].describe().astype(int), '\n')
print('Дисперсия:', np.var(sports['user_score'], ddof=1))
# Out:
# Средний пользовательский рейтинг. Основная статистика распределения.
#
# Жанр Action:
#
# count    1796
# mean        7
# std         1
# min         0
# 25%         6
# 50%         7
# 75%         8
# max         9
# Name: user_score, dtype: int64
#
# Дисперсия: 2.027493768262496
#
# Жанр Sports:
#
# count    1081
# mean        6
# std         1
# min         0
# 25%         6
# 50%         7
# 75%         8
# max         9
# Name: user_score, dtype: int64
#
# Дисперсия: 2.623055812519272

# %% [markdown]
# Выборки имеют разные дисперсии и различаются по размеру. Учтем это при проведении t-теста.
#
# Сформулируем статистические гипотезы из положения о том, что нулевая гипотеза всегда формулируется так, чтобы использовать знак равенства:
#
# H0 — средний пользовательский рейтинг жанров Action и Sports одинаковый.
# H1 — средний пользовательский рейтинг жанров Action и Sports различается.

# %%
# критический уровень статистической значимости зададим 5% поскольку у нас двусторонняя гипотеза и 
# вероятность отклониться от центра распределения в каждую сторону уменьшится до 2,5% 
# и это стандартная величина, обычно использующаяся в t-тесте
alpha = .05 

# поскольку у нас две независимые выборки, используем метод st.ttest_ind()
# equal_var=False - дисперсии выборок не равны
results = st.ttest_ind(
    action['user_score'], 
    sports['user_score'], 
    equal_var=False) 

print('p-значение:', results.pvalue)

# сравним получившееся p-значение с заданным уровнем статистической значимости
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу. Средний пользовательский рейтинг жанров Action и Sports различается.')
else:
    print('Не получилось отвергнуть нулевую гипотезу. Средний пользовательский рейтинг жанров Action и Sports одинаковый')
# Out:
# p-значение: 0.07370217419278534
# Не получилось отвергнуть нулевую гипотезу. Средний пользовательский рейтинг жанров Action и Sports одинаковый

# %% [markdown]
# ### Выводы
#
# Согласно результатам t-теста для независимых выборок с разными дисперсиями:
# 1. Средний пользовательский рейтинг платформ Xbox One и PC не различается.
# 2. Средний пользовательский рейтинг жанров Action и Sports не различается.

# %% [markdown]
# ## Общие выводы

# %% [markdown]
# 1. В результате анализа архива данных из открытых источников о продажах игр, оценок пользователей и экспертов, рейтинга организации ESRB, жанрах на актуальных платформах (PS4, XOne, PC, 3DS, WiiU и PSV) с 2013 по 2016 годы удалось обнаружить ряд закономерностей успешных игр, которые могут быть использованы в планировании рекламных кампаний на 2017 год.
# 2. Если говорить о всех регионах, то с наибольшей степенью вероятности успешная игра будет выпущена на платформе PlayStation 4 (медиана проданных игр: 85 миллионов копий), с меньшей, но достаточно высокой вероятностью на платформе Xbox One (медиана проданных игр: 40 миллионов копий).
# 3. Жанр игры будет: Action (26,4 % проданных игр) или Shooter (21,9%).
# 4. При выборе игры можно не учитывать оценки критиков и пользователей, т.к. связь между уровнем оценки и количеством проданных копий игр незначительная.
# 5. При этом существует региональная специфика. Если для Северной Америки и Европы предпочтение платформ сохраняется, то в случае Японии нужно ориентироваться на мобильные платформы, в первую очередь - это Nintendo 3DS (59,7 % проданных игр), во вторую - PlayStation Vita (16,3 %).
# 6. Жанры остаются те же для Северной Америки и Европы. Среди японских геймеров также популярен жанр Action, но на первом месте жанр Role-Playing.
# 7. Лучший рейтинг ESRB для игры - это М ("от 17 лет"). Но не для Европы, в которой больше покупают игры категорий Т("Подросткам 13—19 лет") и Е ("для всех").

# %% [markdown]
# <div style="border:solid purple 5px; padding: 20px">
# Тобой проделана большая и тщательная работа. Аккуратный код, красивая визуализация, отличная работа с результатами. Есть несколько критических моментов, требующих доработки, но думаю, что ты с ними легко справишься ✋
#
# Если у тебя будут возникать вопросы или же покажется, что что-то я пропустила при проверке, обязательно дай знать — чем тщательнее на этапе учебы будут разобраны детали, тем проще будет применять эти знания на практике.
#
# С нетерпением жду твои правки
#
# ![](https://i.gifer.com/iAe.gif)

# %% [markdown]
# <div class="alert alert-info">
# <b>Исправил там, где понял, что от меня трбуется, а где не понял, спросил) </div>
# <hr>

# %% [markdown]
# <div class="alert alert-success">
# <b> 🤌  Комментарий ревьюера (v.2)</b>
#
# Отличный вышел у нас диалог — давай продолжим в том же духе. Еще чуточку подправить и будет прямо идеально 😄
# </div>
